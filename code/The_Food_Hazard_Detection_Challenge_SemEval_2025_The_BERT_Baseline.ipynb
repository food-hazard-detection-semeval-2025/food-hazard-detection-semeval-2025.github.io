# %% [markdown]
# <a href="https://colab.research.google.com/github/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/blob/main/code/The_Food_Hazard_Detection_Challenge_SemEval_2025_The_BERT_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install torch transformers datasets pandas scikit-learn

# %%
# incidents_rest.csv is the dataset besides the trial
# incidents_sample.csv is the trial dataset

# %%
from transformers import BertTokenizer
import pandas as pd
data = pd.read_csv('incidents_rest.csv', index_col=0)
trial = pd.read_csv('incidents_sample.csv', index_col=0)
trial.sample()
# Out:
#     year  month  day                                              title  \
# 89  2021      3    4  Co-op recalls British 12 Beef Meatballs becaus...
#
#                                product              product-category  \
# 89  other not classified meat products  meat, egg and dairy products
#
#    product-title            hazard hazard-category hazard-title language  \
# 89       (30,38)  plastic fragment  foreign bodies        (0,4)       en
#
#    country
# 89      uk

# %%
import pandas as pd
from datasets import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_scheduler, DataCollatorWithPadding
from torch.utils.data import DataLoader
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm.auto import tqdm
from sklearn.metrics import classification_report

# %%
data.title.str.split().apply(len).describe()
# Out:
# count    4982.000000
# mean       13.286431
# std         5.218730
# min         1.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        44.000000
# Name: title, dtype: float64

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def tokenize_function(examples):
    return tokenizer(examples['title'], padding=True, truncation=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# # Label: `Hazard Category`

# %% [markdown]
# * Choose your target

# %%
label = 'hazard-category' # change this to: 'product-category', 'hazard', 'product' to alter the ground truth
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data[label])

# %% [markdown]
# * Data preprocessing

# %%
# Split the data into training and testing sets
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Convert DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Apply the tokenizer to the dataset
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Create DataCollator to handle padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding=True, max_length=16)

# Convert dataset to PyTorch format
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Create DataLoader objects
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=8, collate_fn=data_collator)
test_dataloader = DataLoader(test_dataset, batch_size=8, collate_fn=data_collator)
# Out:
# Map:   0%|          | 0/3985 [00:00<?, ? examples/s]
# Map:   0%|          | 0/997 [00:00<?, ? examples/s]

# %% [markdown]
# * Choose your model

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(data[label].unique()))
model.to('cuda')  # Move model to GPU if available
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=10, bias=True)
# )

# %% [markdown]
# * Train it

# %%
optimizer = AdamW(model.parameters(), lr=5e-5)

num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

model.train()

progress_bar = tqdm(range(num_training_steps))

for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1497 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %% [markdown]
# * Assess it

# %%
model.eval()
total_predictions = []
with torch.no_grad():
    for batch in test_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        total_predictions.extend([p.item() for p in predictions])

#print(classification_report(test_df.label, total_predictions))
predicted_labels = label_encoder.inverse_transform(total_predictions)
gold_labels = label_encoder.inverse_transform(test_df.label.values)
print(classification_report(gold_labels, predicted_labels, zero_division=0))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
#                                 precision    recall  f1-score   support
#
#                      allergens       0.88      0.89      0.88       348
#                     biological       0.88      0.90      0.89       354
#                       chemical       0.66      0.74      0.70        50
# food additives and flavourings       1.00      0.50      0.67         2
#                 foreign bodies       0.71      0.79      0.75       121
#                          fraud       0.73      0.66      0.69        68
#           organoleptic aspects       0.83      0.45      0.59        11
#                   other hazard       0.73      0.34      0.47        32
#               packaging defect       0.71      0.45      0.56        11
#
#                       accuracy                           0.83       997
#                      macro avg       0.79      0.64      0.69       997
#                   weighted avg       0.83      0.83      0.83       997

# %%
model.save_pretrained("bert_hazard_category")

# %% [markdown]
# # Label: `Product Category`

# %%
label = 'product-category'
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data[label])

# Split the data into training and testing sets
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Convert DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Apply the tokenizer to the dataset
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Create DataCollator to handle padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding=True, max_length=16)

# Convert dataset to PyTorch format
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Create DataLoader objects
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=8, collate_fn=data_collator)
test_dataloader = DataLoader(test_dataset, batch_size=8, collate_fn=data_collator)
# Out:
# Map:   0%|          | 0/3985 [00:00<?, ? examples/s]
# Map:   0%|          | 0/997 [00:00<?, ? examples/s]

# %% [markdown]
# * Train

# %%
model_product_category = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(data[label].unique()))
model_product_category.to('cuda')  # Move model to GPU if available

optimizer = AdamW(model_product_category.parameters(), lr=5e-5)
num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

model_product_category.train()
progress_bar = tqdm(range(num_training_steps))
for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_product_category(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1497 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %% [markdown]
# * Test

# %%
model_product_category.eval()
total_predictions = []
with torch.no_grad():
    for batch in test_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_product_category(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        total_predictions.extend([p.item() for p in predictions])

#print(classification_report(test_df.label, total_predictions, zero_division=0))
predicted_labels = label_encoder.inverse_transform(total_predictions)
gold_labels = label_encoder.inverse_transform(test_df.label.values)
print(classification_report(gold_labels, predicted_labels, zero_division=0))
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.91      0.77      0.83        13
#                       cereals and bakery products       0.79      0.82      0.80       143
#      cocoa and cocoa preparations, coffee and tea       0.85      0.81      0.83        36
#                                     confectionery       0.57      0.53      0.55        30
# dietetic foods, food supplements, fortified foods       0.64      0.69      0.67        26
#                                     fats and oils       1.00      0.57      0.73         7
#                                    feed materials       0.00      0.00      0.00         1
#                    food additives and flavourings       0.00      0.00      0.00         1
#                            food contact materials       0.00      0.00      0.00         2
#                             fruits and vegetables       0.85      0.77      0.80       115
#                                  herbs and spices       0.55      0.57      0.56        21
#                             honey and royal jelly       0.00      0.00      0.00         1
#                                 ices and desserts       0.94      0.89      0.92        56
#                      meat, egg and dairy products       0.86      0.90      0.88       270
#                           non-alcoholic beverages       0.72      0.90      0.80        29
#                      nuts, nut products and seeds       0.80      0.67      0.73        48
#                        other food product / mixed       1.00      0.07      0.13        14
#                                          pet feed       1.00      1.00      1.00         1
#                        prepared dishes and snacks       0.51      0.54      0.52        91
#                                           seafood       0.93      0.96      0.95        45
#              soups, broths, sauces and condiments       0.65      0.87      0.74        46
#                                 sugars and syrups       0.00      0.00      0.00         1
#
#                                          accuracy                           0.78       997
#                                         macro avg       0.62      0.56      0.57       997
#                                      weighted avg       0.78      0.78      0.77       997

# %%
model_product_category.save_pretrained("bert_product_category")

# %% [markdown]
# # Label: `Hazard`

# %%
label = 'hazard'
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data[label])

# Split the data into training and testing sets
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Convert DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Apply the tokenizer to the dataset
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Create DataCollator to handle padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding=True, max_length=16)

# Convert dataset to PyTorch format
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Create DataLoader objects
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=8, collate_fn=data_collator)
test_dataloader = DataLoader(test_dataset, batch_size=8, collate_fn=data_collator)
# Out:
# Map:   0%|          | 0/3985 [00:00<?, ? examples/s]
# Map:   0%|          | 0/997 [00:00<?, ? examples/s]

# %%
model_hazard = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(data[label].unique()))
model_hazard.to('cuda')  # Move model to GPU if available

optimizer = AdamW(model_hazard.parameters(), lr=5e-5)

num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

model_hazard.train()

progress_bar = tqdm(range(num_training_steps))

for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_hazard(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1497 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
model_hazard.eval()
total_predictions = []
with torch.no_grad():
    for batch in test_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_hazard(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        total_predictions.extend([p.item() for p in predictions])

#print(classification_report(test_df.label, total_predictions, zero_division=0))
predicted_labels = label_encoder.inverse_transform(total_predictions)
gold_labels = label_encoder.inverse_transform(test_df.label.values)
print(classification_report(gold_labels, predicted_labels, zero_division=0))
# Out:
#                                                  precision    recall  f1-score   support
#
#                                       Aflatoxin       0.00      0.00      0.00         1
#                                 alcohol content       0.00      0.00      0.00         1
#                                       allergens       0.00      0.00      0.00         3
#                                          almond       0.57      0.89      0.70         9
#                          antibiotics, vet drugs       0.00      0.00      0.00         1
#                                   bacillus spp.       0.00      0.00      0.00         3
#                            bad smell / off odor       0.00      0.00      0.00         1
#                                   bone fragment       0.00      0.00      0.00         1
#                               bulging packaging       0.00      0.00      0.00         2
#                                          cashew       0.00      0.00      0.00         3
#                     celery and products thereof       0.00      0.00      0.00         1
#                                         cereals       0.00      0.00      0.00         1
#  cereals containing gluten and products thereof       0.51      0.51      0.51        37
#                                        chemical       0.00      0.00      0.00         1
#                chemical compound (high content)       0.00      0.00      0.00         2
#                chemical compound (unauthorised)       0.00      0.00      0.00         3
#                                        chlorine       0.00      0.00      0.00         1
#                           clostridium botulinum       0.46      0.75      0.57         8
#                                       coliforms       0.00      0.00      0.00         1
#                                     contaminant       0.00      0.00      0.00         1
#                                 cronobacter spp       0.00      0.00      0.00         1
#                crustaceans and products thereof       0.00      0.00      0.00         1
#                                      cyclospora       0.00      0.00      0.00         2
#                                  dairy products       0.00      0.00      0.00         1
#                               damaged packaging       0.00      0.00      0.00         3
#                     e 425 - konjac unauthorised       0.00      0.00      0.00         1
#                       eggs and products thereof       0.77      0.52      0.62        44
#                                   enteroviruses       0.00      0.00      0.00         3
#                                escherichia coli       0.56      0.79      0.65        47
#                       fish and products thereof       1.00      0.17      0.29         6
#                                  foreign bodies       0.00      0.00      0.00         8
#                                  glass fragment       0.71      0.50      0.59        24
#                                        hazelnut       0.00      0.00      0.00         1
#                                    heavy metals       0.00      0.00      0.00         5
#                          high content of copper       0.00      0.00      0.00         1
#                             improper conditions       0.00      0.00      0.00         2
#                              incorrect labeling       0.00      0.00      0.00         7
#                          incorrect use by dates       0.50      0.33      0.40         3
#                                         insects       1.00      0.67      0.80         3
#                               inspection issues       0.59      1.00      0.74        17
#            insufficient labelling/documentation       0.00      0.00      0.00         5
#                        labelling/misdescription       0.00      0.00      0.00         9
#                          listeria monocytogenes       0.74      0.76      0.75       134
#                                    listeria spp       0.00      0.00      0.00         1
#                                  metal fragment       0.49      0.58      0.53        33
#                   microbiological contamination       0.00      0.00      0.00         5
#                       milk and products thereof       0.53      0.82      0.64       111
#                                     misbranding       0.00      0.00      0.00         3
#                                  misdescription       0.00      0.00      0.00         5
#                   molluscs and products thereof       0.00      0.00      0.00         1
#                                          moulds       0.30      0.78      0.44         9
#                    mustard and products thereof       0.90      0.82      0.86        11
#                       non compliance with HACCP       0.00      0.00      0.00         1
#                                       norovirus       0.67      0.80      0.73         5
#                                      novel food       0.00      0.00      0.00         1
#                                            nuts       0.00      0.00      0.00         4
#                                      ochratoxin       0.00      0.00      0.00         1
#                                           other       0.21      0.55      0.31        20
#                            other not classified       0.00      0.00      0.00         9
#           other not classified allergen hazards       0.00      0.00      0.00         2
#         other not classified biological hazards       0.00      0.00      0.00         5
#           other not classified chemical hazards       0.00      0.00      0.00         4
# other not classified hazards for foreign bodies       0.00      0.00      0.00         2
#                                packaging defect       0.00      0.00      0.00         6
#                                            pahs       0.00      0.00      0.00         2
#                             pathogenic bacteria       0.00      0.00      0.00         2
#                                         patulin       0.00      0.00      0.00         2
#                    peanuts and products thereof       0.64      0.57      0.61        47
#                                       pecan nut       1.00      0.33      0.50         3
#                                  phenylpyrazole       0.00      0.00      0.00         2
#                                  pieces of wood       0.00      0.00      0.00         1
#                                   pistachio nut       0.00      0.00      0.00         3
#                                plastic fragment       0.47      0.84      0.61        43
#                polycyclic aromatic hydrocarbons       0.00      0.00      0.00         1
#                             poor hygienic state       0.00      0.00      0.00         3
#                   poor or insufficient controls       0.00      0.00      0.00         4
#                                      processing       1.00      0.44      0.62         9
#                product category/characteristics       0.00      0.00      0.00         1
#                                pseudomonas spp.       0.00      0.00      0.00         3
#                                rubber fragments       0.00      0.00      0.00         6
#                                      salmonella       0.70      0.81      0.75       118
#               sesame seeds and products thereof       1.00      0.38      0.55         8
#                   soybeans and products thereof       0.31      0.46      0.37        28
#                   specified risk material (srm)       0.00      0.00      0.00         1
#                                        spoilage       1.00      0.50      0.67         8
#                      staphylococcal enterotoxin       0.00      0.00      0.00         0
#                                  staphylococcus       0.00      0.00      0.00         3
#                             sulphates/sulphites       0.00      0.00      0.00         2
#                                 sulphur dioxide       0.00      0.00      0.00         1
#                   sulphur dioxide and sulphites       0.75      0.80      0.77        15
#                               taste disturbance       0.00      0.00      0.00         1
#  too high content of tetrahydrocannabinol (THC)       0.00      0.00      0.00         2
#                                           toxin       0.00      0.00      0.00         2
#                     unauthorised colour sudan 4       0.00      0.00      0.00         1
#                             unauthorised import       0.00      0.00      0.00         3
#              unauthorised placing on the market       0.00      0.00      0.00         1
#           unauthorised substance ethylene oxide       0.73      0.89      0.80         9
#               unauthorised substance sildenafil       0.00      0.00      0.00         1
#                             undeclared additive       0.00      0.00      0.00         2
#                                           virus       0.00      0.00      0.00         1
#                                          walnut       1.00      0.67      0.80         9
#                                          yeasts       0.00      0.00      0.00         1
#
#                                        accuracy                           0.58       997
#                                       macro avg       0.19      0.18      0.17       997
#                                    weighted avg       0.52      0.58      0.53       997

# %%
model_hazard.save_pretrained("bert_hazard")

# %% [markdown]
# # Label: `product`

# %%
label = 'product'
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data[label])

# Split the data into training and testing sets
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Convert DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Apply the tokenizer to the dataset
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Create DataCollator to handle padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding=True, max_length=16)

# Convert dataset to PyTorch format
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Create DataLoader objects
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=8, collate_fn=data_collator)
test_dataloader = DataLoader(test_dataset, batch_size=8, collate_fn=data_collator)
# Out:
# Map:   0%|          | 0/3985 [00:00<?, ? examples/s]
# Map:   0%|          | 0/997 [00:00<?, ? examples/s]

# %%
model_product = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(data[label].unique()))
model_product.to('cuda')  # Move model to GPU if available

optimizer = AdamW(model_product.parameters(), lr=5e-5)
num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)
model_product.train()
progress_bar = tqdm(range(num_training_steps))
for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_product(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1497 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2717: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
model_product.eval()
total_predictions = []
with torch.no_grad():
    for batch in test_dataloader:
        batch = {k: v.to('cuda') for k, v in batch.items()}  # Move batch to GPU if available
        outputs = model_product(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        total_predictions.extend([p.item() for p in predictions])

#print(classification_report(test_df.label, total_predictions, zero_division=0))
predicted_labels = label_encoder.inverse_transform(total_predictions)
gold_labels = label_encoder.inverse_transform(test_df.label.values)
print(classification_report(gold_labels, predicted_labels, zero_division=0))
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                         Catfishes (freshwater)       0.00      0.00      0.00         2
#                                          Fishes not identified       0.46      1.00      0.63         6
#                                             Groupers (generic)       0.00      0.00      0.00         1
#                                     Pangas catfishes (generic)       0.00      0.00      0.00         1
#                            Precooked cooked pork meat products       0.00      0.00      0.00         4
#                                                  Veggie Burger       0.00      0.00      0.00         1
#                                            alcoholic beverages       0.00      0.00      0.00         2
#                                                alfalfa sprouts       0.00      0.00      0.00         4
#                                                          algae       0.00      0.00      0.00         2
#                                          all purpose seasoning       0.00      0.00      0.00         1
#                                                       allspice       0.00      0.00      0.00         1
#                                                    almond milk       0.00      0.00      0.00         1
#                                                almond products       0.00      0.00      0.00         1
#                                                        almonds       0.00      0.00      0.00         4
#                                                     angus beef       0.00      0.00      0.00         2
#                                                    apple juice       0.29      0.50      0.36         4
#                                                         apples       0.00      0.00      0.00         0
#                                  assorted bread roll selection       0.00      0.00      0.00         2
#                                assortment of filled chocolates       0.00      0.00      0.00         1
#                                                      baby food       0.00      0.00      0.00         4
#                                                   baby spinach       0.00      0.00      0.00         4
#                                                bakery products       0.00      0.00      0.00         4
#                                                        baklava       0.00      0.00      0.00         1
#                                                 barbecue sauce       0.00      0.00      0.00         1
#                                                           bars       0.00      0.00      0.00         2
#                                              basil pesto sauce       0.05      0.67      0.09         3
#                                                     bean paste       0.00      0.00      0.00         1
#                                                           beef       0.00      0.00      0.00         6
#                                                  beef products       0.00      0.00      0.00         4
#                                                    beef stewed       0.00      0.00      0.00         1
#                                                    beef tongue       0.00      0.00      0.00         1
#                                                           beer       0.03      1.00      0.05         3
#                                                    biscuit mix       0.00      0.00      0.00         1
#                                                       biscuits       0.00      0.00      0.00         9
#                                                   black pepper       0.00      0.00      0.00         1
#                                                   blackberries       0.00      0.00      0.00         1
#                                       bloody mary beverage mix       0.00      0.00      0.00         1
#                                                    blue cheese       0.00      0.00      0.00         5
#                                                    blueberries       0.00      0.00      0.00         1
#                                                           boar       0.00      0.00      0.00         2
#                            boletus mushrooms, stems and pieces       0.00      0.00      0.00         1
#                                                  boneless beef       0.00      0.00      0.00         1
#                                          bottled mineral water       0.00      0.00      0.00         1
#                                                  bottled water       0.00      0.00      0.00         3
#                                                          bread       0.40      0.67      0.50         3
#                                    bread and products therefor       0.00      0.00      0.00         1
#                                                    bread crumb       0.00      0.00      0.00         1
#                                              breakfast cereals       0.00      0.00      0.00         5
#                                                    brie cheese       0.00      0.00      0.00         1
#                                                       broccoli       0.00      0.00      0.00         1
#                                                         broths       0.00      0.00      0.00         1
#                                                           buns       0.00      0.00      0.00         3
#                                         burrito (ready to eat)       0.00      0.00      0.00         1
#                                                         butter       0.00      0.00      0.00         1
#                                                        cabbage       0.00      0.00      0.00         1
#                                                          cakes       0.27      0.72      0.39        18
#                                                      camembert       0.00      0.00      0.00         1
#                                                        candies       0.00      0.00      0.00         5
#                                                 canned spinach       0.00      0.00      0.00         1
#                                                  caramel bites       0.00      0.00      0.00         1
#                             carps, barbels and other cyprinids       0.00      0.00      0.00         1
#                                                         cashew       0.00      0.00      0.00         2
# cattle from which the milk was used to produce raw milk cheese       0.00      0.00      0.00         1
#                                                   cbd products       0.00      0.00      0.00         1
#                                                         cereal       0.00      0.00      0.00         2
#                                                    cereal bars       0.00      0.00      0.00         2
#                                                        cereals       0.00      0.00      0.00         1
#                                    cereals and bakery products       0.00      0.00      0.00         1
#                                                 cheddar cheese       0.00      0.00      0.00         3
#                                                         cheese       0.08      0.88      0.14         8
#                                    cheese - made from raw milk       0.00      0.00      0.00         1
#                                                cheese - melted       0.00      0.00      0.00         1
#                                                     cheese dip       0.00      0.00      0.00         1
#                                                cheese products       0.00      0.00      0.00         1
#                                                  cheese spread       0.00      0.00      0.00         1
#                                                 cheesy spirals       0.00      0.00      0.00         1
#                                                     chia seeds       0.00      0.00      0.00         2
#                                                        chicken       0.00      0.00      0.00         7
#                               chicken and chicken preparations       0.00      0.00      0.00         1
#                                         chicken based products       0.25      0.97      0.40        30
#                                                 chicken breast       0.00      0.00      0.00         4
#                                                chicken dippers       0.00      0.00      0.00         1
#                                          chicken meat products       0.00      0.00      0.00         1
#                                            chicken noodle soup       0.00      0.00      0.00         1
#                                                    chicken pie       0.00      0.00      0.00         1
#                                           chicken preparations       0.00      0.00      0.00         3
#                                                      chickpeas       0.00      0.00      0.00         1
#                                          chilled chicken parts       0.00      0.00      0.00         1
#                                                 chilled salads       0.00      0.00      0.00         2
#                                                  chilli pickle       0.00      0.00      0.00         1
#                                                  chilli powder       0.00      0.00      0.00         1
#                                                      chocolate       0.00      0.00      0.00         1
#                               chocolate and chocolate products       0.00      0.00      0.00         1
#                                                 chocolate bars       0.00      0.00      0.00         8
#                                                chocolate chips       0.00      0.00      0.00         1
#                                        chocolate confectionery       0.00      0.00      0.00         1
#                                                 chocolate eggs       0.00      0.00      0.00         5
#                                             chocolate products       0.00      0.00      0.00         7
#                                                     chocolates       0.00      0.00      0.00         1
#                                                        chorizo       0.00      0.00      0.00         3
#                                                chorizo sausage       0.00      0.00      0.00         3
#                                                          cider       0.00      0.00      0.00         3
#                                                       cinnamon       0.00      0.00      0.00         2
#                                                          clams       0.00      0.00      0.00         2
#                                                  coconut juice       0.00      0.00      0.00         2
#                                                   coconut milk       0.00      0.00      0.00         1
#                                             coconut milk drink       0.00      0.00      0.00         3
#                                                    coconut oil       0.00      0.00      0.00         1
#                                                       coconuts       0.40      0.80      0.53         5
#                                                   coffee beans       0.00      0.00      0.00         1
#                                                     cola drink       0.00      0.00      0.00         1
#                                                        colours       0.00      0.00      0.00         1
#                                            concentrated apples       0.00      0.00      0.00         1
#                                                 cooked chicken       0.00      0.00      0.00         2
#                                                     cooked ham       0.00      0.00      0.00         2
#                                                cooked sausages       0.00      0.00      0.00         2
#                                                        cookies       0.28      0.95      0.43        19
#                                                  cooking sauce       0.00      0.00      0.00         1
#                                                           corn       0.00      0.00      0.00         6
#                                                cow milk cheese       0.00      0.00      0.00         1
#                                                       crackers       0.00      0.00      0.00         4
#                                                   cream cheese       0.00      0.00      0.00         1
#                                            cream chocolate pie       0.00      0.00      0.00         1
#                                                      crepe mix       0.00      0.00      0.00         1
#                                                     crispbread       0.00      0.00      0.00         1
#                                                     croissants       0.00      0.00      0.00         2
#                                             crushed red pepper       0.00      0.00      0.00         1
#                                                   cumin powder       0.00      0.00      0.00         1
#                                                       cupcakes       0.00      0.00      0.00         2
#                                                     cured loin       0.00      0.00      0.00         1
#                                                cured pork meat       0.00      0.00      0.00         1
#                                                        custard       0.00      0.00      0.00         2
#                                  dark chocolate coated almonds       0.00      0.00      0.00         1
#                                                dark chocolates       0.12      1.00      0.21         3
#                                                          dates       0.00      0.00      0.00         1
#                                                       desserts       0.00      0.00      0.00         9
#                                             dietary supplement       0.00      0.00      0.00         5
#              dietetic foods, food supplements, fortified foods       0.00      0.00      0.00         1
#                                                      dip-sauce       0.00      0.00      0.00         3
#                                                         donuts       0.00      0.00      0.00         2
#                                                       dressing       0.00      0.00      0.00         2
#                                                 dried apricots       0.00      0.00      0.00         1
#                                                dried beef meat       0.40      0.67      0.50         3
#                                              dried brown beans       0.00      0.00      0.00         1
#                                           dried chilli peppers       0.00      0.00      0.00         2
#                                                  dried coconut       0.00      0.00      0.00         2
#                                              dried cranberries       0.00      0.00      0.00         2
#                                                     dried figs       0.00      0.00      0.00         2
#                                                   dried fruits       0.00      0.00      0.00         1
#                                                dried mushrooms       0.00      0.00      0.00         1
#                                                  dried pangash       0.00      0.00      0.00         1
#                                                    dried plums       0.00      0.00      0.00         2
#                                            dried pork sausages       0.00      0.00      0.00         1
#                                             dried strawberries       0.00      0.00      0.00         1
#                                                   drink powder       0.00      0.00      0.00         1
#                                      drinking chocolate powder       0.00      0.00      0.00         1
#                                                        dry ham       0.00      0.00      0.00         1
#                                                           duck       0.00      0.00      0.00         2
#                                                      dumplings       0.00      0.00      0.00         3
#                                                   egg products       0.00      0.00      0.00         1
#                                                      egg rolls       0.00      0.00      0.00         1
#                                                           eggs       0.00      0.00      0.00         5
#                                        energy and protein bars       0.00      0.00      0.00         1
#                                                    fajita meal       0.00      0.00      0.00         1
#                                                 feed materials       0.00      0.00      0.00         1
#                                                   fennel seeds       0.00      0.00      0.00         1
#                                                    feta cheese       0.00      0.00      0.00         1
#                                         fish and fish products       0.00      0.00      0.00         1
#                                                       fish roe       0.00      0.00      0.00         1
#                                     flounders, halibuts, soles       0.00      0.00      0.00         1
#                                                          flour       0.43      1.00      0.60         6
#                                                      foie gras       0.00      0.00      0.00         1
#                                                food supplement       0.00      0.00      0.00         3
#                                                   fresh apples       0.00      0.00      0.00         1
#                                                   fresh cheese       0.00      0.00      0.00         1
#                                                fresh mushrooms       1.00      0.50      0.67         4
#                                                  fresh parsley       0.00      0.00      0.00         0
#                                                     fresh pork       0.00      0.00      0.00         1
#                             fresh processed beef meat products       0.00      0.00      0.00         1
#                                               fresh vegetables       0.00      0.00      0.00         1
#                                            frozen beef patties       0.00      0.00      0.00         1
#                                           frozen beef products       0.00      0.00      0.00         3
#                                             frozen beef tongue       0.00      0.00      0.00         1
#                                            frozen bourbon ribs       0.00      0.00      0.00         1
#                                          frozen breaded turkey       0.00      0.00      0.00         1
#                                                frozen broccoli       0.00      0.00      0.00         1
#                                                 frozen burgers       0.00      0.00      0.00         1
#                                                 frozen chicken       0.00      0.00      0.00         1
#                                     frozen dumplings with pork       0.00      0.00      0.00         1
#                                            frozen fish fillets       0.00      0.00      0.00         2
#                                             frozen green beans       0.00      0.00      0.00         1
#                                             frozen hash browns       0.00      0.00      0.00         2
#                                                    frozen peas       0.00      0.00      0.00         3
#                                                 frozen peppers       0.00      0.00      0.00         1
#                                                     frozen pie       0.00      0.00      0.00         1
#                                                   frozen pizza       0.00      0.00      0.00         3
#                                       frozen pork preparations       0.00      0.00      0.00         2
#                                                frozen potatoes       0.00      0.00      0.00         1
#                                   frozen ready to eat products       0.00      0.00      0.00         1
#                                                frozen sausages       0.00      0.00      0.00         1
#                                     frozen spicy chicken wings       0.00      0.00      0.00         1
#                                              frozen vegetables       0.00      0.00      0.00         2
#                                                    fruit juice       0.00      0.00      0.00         1
#                                                     fruit pies       0.00      0.00      0.00         1
#                                                    fruit punch       0.00      0.00      0.00         1
#                                          fruits and vegetables       0.00      0.00      0.00         1
#                                                  garlic pickle       0.00      0.00      0.00         1
#                                                  garlic powder       0.00      0.00      0.00         2
#                                                  ginger powder       0.00      0.00      0.00         1
#                                                 ginseng powder       0.00      0.00      0.00         1
#                                              gluten free bread       0.00      0.00      0.00         1
#                                                    goat cheese       0.00      0.00      0.00         1
#                                        golden raisins/sultanas       0.00      0.00      0.00         1
#                                              gorgonzola cheese       0.00      0.00      0.00         3
#                                                        granola       0.00      0.00      0.00         2
#                                                         grapes       0.00      0.00      0.00         1
#                                                 grated coconut       0.00      0.00      0.00         1
#                                                    green pesto       0.00      0.00      0.00         2
#                                                  green raisins       0.00      0.00      0.00         1
#                                           grissini breadsticks       0.00      0.00      0.00         1
#                                                    ground beef       0.13      0.92      0.23        12
#                                               ground beef meat       0.00      0.00      0.00         1
#                                            ground black pepper       0.00      0.00      0.00         1
#                                                halloumi cheese       0.00      0.00      0.00         2
#                                                          halva       0.00      0.00      0.00         2
#                                                            ham       0.00      0.00      0.00         6
#                                                        herring       0.00      0.00      0.00         2
#                                                          honey       0.00      0.00      0.00         1
#                                                       hot dogs       0.00      0.00      0.00         1
#                                                      ice cream       0.42      0.98      0.59        44
#                                                     ice sticks       0.00      0.00      0.00         1
#                                                 infant formula       0.00      0.00      0.00         1
#                                                instant noodles       0.00      0.00      0.00         2
#                                                            jam       0.00      0.00      0.00         5
#                                                        jellies       0.00      0.00      0.00         1
#                                                    juice drink       0.00      0.00      0.00         1
#                                                         juices       0.00      0.00      0.00         1
#                                                           kale       0.00      0.00      0.00         1
#                                                        ketchup       0.00      0.00      0.00         1
#                                                           lamb       0.00      0.00      0.00         1
#                                                        lasagne       0.00      0.00      0.00         1
#                                                   lentils stew       0.00      0.00      0.00         1
#                                                        lettuce       0.00      0.00      0.00         2
#                                         liquid food supplement       0.00      0.00      0.00         1
#                                                      liquorice       0.00      0.00      0.00         1
#                                                         lokoum       0.00      0.00      0.00         1
#                                                      lollipops       0.00      0.00      0.00         2
#                                                 macadamia nuts       0.00      0.00      0.00         3
#                                                       mackerel       0.00      0.00      0.00         1
#                                                          maize       0.00      0.00      0.00         1
#                                                       marzipan       0.00      0.00      0.00         1
#                                      mashed chickpeas (hummus)       0.00      0.00      0.00         2
#                    meat and meat products (other than poultry)       0.00      0.00      0.00         1
#                                                    melon seeds       0.00      0.00      0.00         1
#                                                           milk       0.41      0.90      0.56        10
#                                 milk chocolate covered raisins       0.00      0.00      0.00         2
#                                                milk chocolates       0.00      0.00      0.00         2
#                                                    milk powder       0.00      0.00      0.00         1
#                                                  milk proteins       0.00      0.00      0.00         1
#                                                millet porridge       0.00      0.00      0.00         1
#                                               minced beef meat       0.00      0.00      0.00         1
#                                                  mineral water       0.00      0.00      0.00         2
#                                                 mineral waters       0.00      0.00      0.00         1
#                                                 mint chocolate       0.00      0.00      0.00         1
#                                    mitragyna speciosa (kratom)       0.00      0.00      0.00         1
#                                                     mozzarella       0.00      0.00      0.00         2
#                                              mozzarella cheese       0.00      0.00      0.00         1
#                                                         muesli       0.00      0.00      0.00         3
#                                                        muffins       0.00      0.00      0.00         4
#                                                      mushrooms       0.00      0.00      0.00         2
#                                                        mustard       0.00      0.00      0.00         1
#                                                    nacho chips       0.00      0.00      0.00         1
#                                             non-alcoholic beer       0.00      0.00      0.00         1
#                                        non-alcoholic beverages       0.00      0.00      0.00         1
#                                                    noodle soup       0.00      0.00      0.00         2
#                                                        noodles       0.00      0.00      0.00         4
#                                                         nougat       0.00      0.00      0.00         1
#                                             nut and raisin mix       0.00      0.00      0.00         1
#                                                    nut mixture       0.00      0.00      0.00         1
#                                                nutrition shake       0.00      0.00      0.00         1
#                                         nuts and nuts products       0.00      0.00      0.00         1
#                                                           oats       0.00      0.00      0.00         3
#                                                        octopus       0.00      0.00      0.00         1
#                                                      olive oil       0.00      0.00      0.00         1
#                                                         onions       0.64      1.00      0.78         7
#                                                   orange juice       0.00      0.00      0.00         1
#                                            organic coconut oil       0.00      0.00      0.00         1
#                                                  organic dates       0.00      0.00      0.00         1
#                                                   organic tofu       0.00      0.00      0.00         1
#                                           other dairy products       0.00      0.00      0.00         7
#                             other not classified meat products       0.00      0.00      0.00         7
#                                            other types of meat       0.00      0.00      0.00         2
#                                       other water-based drinks       0.00      0.00      0.00         1
#                                                        oysters       1.00      1.00      1.00         3
#                                                       palm oil       0.00      0.00      0.00         2
#                                                       pancakes       0.00      0.00      0.00         2
#                                                         papaya       0.00      0.00      0.00         1
#                                                          pasta       0.00      0.00      0.00         3
#                                                 pasta products       0.00      0.00      0.00         3
#                                                    pasta salad       0.00      0.00      0.00         1
#                                                    pasta sauce       0.00      0.00      0.00         1
#                                                pastry products       0.00      0.00      0.00         5
#                                                        peanuts       0.16      0.33      0.21         9
#                                                     pear juice       0.00      0.00      0.00         1
#                                                          pears       0.00      0.00      0.00         1
#                                                      pepperoni       0.00      0.00      0.00         1
#                                      pesto sauce (pesto verde)       0.00      0.00      0.00         1
#                                                       pet feed       0.00      0.00      0.00         1
#                                               pickled beetroot       0.00      0.00      0.00         1
#                                                pig meat - pork       0.00      0.00      0.00         1
#                                                      pine nuts       0.00      0.00      0.00         1
#                                                 pistachio nuts       0.58      1.00      0.74         7
#                                                          pizza       0.00      0.00      0.00         6
#                                                       plastics       0.00      0.00      0.00         1
#                                                    pomegranate       0.00      0.00      0.00         1
#                                                          poppy       0.00      0.00      0.00         1
#                                                   porcine lard       0.00      0.00      0.00         1
#                                                      pork meat       0.00      0.00      0.00         1
#                                                       pork pie       0.00      0.00      0.00         1
#                                                   pork sausage       0.00      0.00      0.00         2
#                                                   potato chips       0.60      1.00      0.75         3
#                                              potato croquettes       0.00      0.00      0.00         1
#                                                   potato salad       0.00      0.00      0.00         2
#                                                       potatoes       0.00      0.00      0.00         4
#                                                        poultry       0.00      0.00      0.00         1
#                         poultry meat and poultry meat products       0.00      0.00      0.00         1
#                                               powder seasoning       0.00      0.00      0.00         1
#                                                         prawns       0.00      0.00      0.00         2
#                                            prebaked apple pies       0.00      0.00      0.00         1
#                            precooked cooked beef meat products       0.00      0.00      0.00         2
#                                                prepacked salad       0.00      0.00      0.00         2
#                                                  prepared dish       0.00      0.00      0.00         1
#                                                prepared salads       0.00      0.00      0.00         4
#                                                  pretzel stick       0.00      0.00      0.00         2
#                                                    protein bar       0.00      0.00      0.00         3
#                                                 protein powder       0.00      0.00      0.00         2
#                                                           pâté       0.00      0.00      0.00         2
#                                                         quinoa       0.00      0.00      0.00         1
#                                              quorn preparation       0.00      0.00      0.00         1
#                                                    raspberries       0.00      0.00      0.00         3
#                                                        ravioli       0.00      0.00      0.00         1
#                                                  raw beef meat       0.00      0.00      0.00         1
#                                           raw goat milk cheese       0.00      0.00      0.00         1
#                                                       raw milk       0.00      0.00      0.00         1
#                                      ready to eat - cook meals       0.11      0.07      0.09        14
#                                                           rice       0.00      0.00      0.00         1
#                                                     rice cakes       0.00      0.00      0.00         2
#                                       rice cereal for children       0.00      0.00      0.00         1
#                                                     rice flour       0.00      0.00      0.00         1
#                                                     rice snack       0.00      0.00      0.00         3
#                                                 ricotta cheese       0.00      0.00      0.00         1
#                                                          rolls       0.00      0.00      0.00         1
#                                                         salads       0.14      0.91      0.25        11
#                                                         salami       0.00      0.00      0.00         4
#                                                         salmon       0.41      1.00      0.58        11
#                                                  salted radish       0.00      0.00      0.00         1
#                                                     sandwiches       0.67      0.31      0.42        13
#                                                          sauce       0.00      0.00      0.00         5
#                                                         sauces       0.00      0.00      0.00         3
#                                                        sausage       0.12      0.40      0.19         5
#                                               sausage products       0.00      0.00      0.00         4
#                                                      seasoning       0.00      0.00      0.00         3
#                                               semi-soft cheese       0.00      0.00      0.00         2
#                                 semolina and products therefor       0.00      0.00      0.00         1
#                                                         sesame       0.00      0.00      0.00         3
#                                                   sesame paste       0.00      0.00      0.00         3
#                                                sesame seed oil       0.00      0.00      0.00         1
#                                                   sesame seeds       0.00      0.00      0.00         1
#                                                        shrimps       0.00      0.00      0.00         3
#                                                     sliced ham       0.00      0.00      0.00         1
#                                                 smoked sausage       0.00      0.00      0.00         1
#                                                       smoothie       0.00      0.00      0.00         1
#                                                 snack crackers       0.00      0.00      0.00         1
#                                                      snack mix       0.00      0.00      0.00         1
#                                                    soft cheese       0.00      0.00      0.00         1
#                                                           soup       0.46      0.75      0.57         8
#                                               soy milk product       0.00      0.00      0.00         1
#                                                      soy sauce       0.00      0.00      0.00         1
#                                                   soya product       0.00      0.00      0.00         1
#                                                         spices       0.00      0.00      0.00         2
#                                          spicy chicken skewers       0.00      0.00      0.00         1
#                                                    spicy sauce       0.00      0.00      0.00         1
#                                                 spinach leaves       0.00      0.00      0.00         1
#                                                        spirits       0.00      0.00      0.00         1
#                                                         spread       0.00      0.00      0.00         3
#                                                   spring rolls       0.00      0.00      0.00         3
#                                                   spring water       0.00      0.00      0.00         2
#                                                      sprinkles       0.00      0.00      0.00         1
#                                                        sprouts       0.00      0.00      0.00         3
#           structured/textured fish meat products or fish paste       0.00      0.00      0.00         1
#                                                 stuffed pastry       0.00      0.00      0.00         2
#                                                          sugar       0.00      0.00      0.00         1
#                                                 sunflower seed       0.00      0.00      0.00         4
#                                                     taco sauce       0.00      0.00      0.00         1
#                                                         tahini       0.14      0.50      0.22         2
#                                          tahini (sesame paste)       0.00      0.00      0.00         1
#                                                            tea       0.00      0.00      0.00         2
#                                    thermal processed beef meat       0.00      0.00      0.00         5
#                                    thermal processed pork meat       0.33      0.23      0.27        13
#                                                           tofu       0.00      0.00      0.00         2
#                                                   tomato sauce       0.00      0.00      0.00         2
#                                                       tomatoes       0.00      0.00      0.00         1
#                                                         trouts       0.00      0.00      0.00         1
#                                                           tuna       0.00      0.00      0.00         1
#                                                     tuna salad       0.00      0.00      0.00         1
#                                 turkey and turkey preparations       0.00      0.00      0.00         4
#                                                turkey sandwich       0.00      0.00      0.00         2
#                                                 tzatziki sauce       0.00      0.00      0.00         1
#                                   vacuum packed marinated pork       0.00      0.00      0.00         1
#                                                 vanilla powder       0.00      0.00      0.00         1
#                                        various bakery products       0.00      0.00      0.00         1
#                                                various cheeses       0.00      0.00      0.00         1
#                                          various meat products       0.00      0.00      0.00         1
#                                         various pasta products       0.00      0.00      0.00         1
#                                           various poultry meat       0.00      0.00      0.00         1
#                                 various vegetable preparations       0.00      0.00      0.00         1
#                                         varnishes and coatings       0.00      0.00      0.00         1
#                                                           veal       0.00      0.00      0.00         5
#                                                      veal meat       0.00      0.00      0.00         1
#                                                 vegan sausages       0.00      0.00      0.00         1
#                                       vegetable based products       0.00      0.00      0.00         1
#                                               vegetable burger       0.00      0.00      0.00         1
#                                                  vegetable mix       0.00      0.00      0.00         2
#                                              vegetable samosas       0.00      0.00      0.00         2
#                                                vegetable snack       0.00      0.00      0.00         1
#                                                     vegetables       0.00      0.00      0.00         1
#                                                        vinegar       0.00      0.00      0.00         1
#                                                       vitamins       0.00      0.00      0.00         1
#                                                        waffles       0.00      0.00      0.00         3
#                                             weight loss coffee       0.00      0.00      0.00         1
#                                            white lasagna sauce       0.00      0.00      0.00         1
#                                             white mould cheese       0.00      0.00      0.00         1
#                                                           wine       0.00      0.00      0.00         3
#                                                          wraps       0.00      0.00      0.00         4
#                                                        yoghurt       0.00      0.00      0.00         6
#
#                                                       accuracy                           0.22       997
#                                                      macro avg       0.02      0.05      0.03       997
#                                                   weighted avg       0.10      0.22      0.12       997

# %%
model_product.save_pretrained("bert_product")
tokenizer.save_pretrained("bert_tokenizer")
# Out:
# ('bert_tokenizer/tokenizer_config.json',
#  'bert_tokenizer/special_tokens_map.json',
#  'bert_tokenizer/vocab.txt',
#  'bert_tokenizer/added_tokens.json')

# %%
# !zip bert_baseline.zip bert_*
# Out:
#   adding: bert_hazard/ (stored 0%)
#   adding: bert_hazard_category/ (stored 0%)
#   adding: bert_product/ (stored 0%)
#   adding: bert_product_category/ (stored 0%)
#   adding: bert_tokenizer/ (stored 0%)

# %% [markdown]
# # Loading a trained baseline

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

def predict(texts, model_path, tokenizer_path="bert_tokenizer"):
    # Load the saved tokenizer
    tokenizer = BertTokenizer.from_pretrained(tokenizer_path)

    # Load the saved model
    model = BertForSequenceClassification.from_pretrained(model_path)

    # Move model to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Tokenize the input texts
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")

    # Move inputs to the same device as the model
    inputs = {key: value.to(device) for key, value in inputs.items()}

    # Set the model to evaluation mode
    model.eval()

    # Make predictions
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)

    return predictions

# %%
from sklearn.metrics import f1_score

def compute_score(hazards_true, products_true, hazards_pred, products_pred):
  # compute f1 for hazards:
  f1_hazards = f1_score(
    hazards_true,
    hazards_pred,
    average='macro'
  )

  # compute f1 for products:
  f1_products = f1_score(
    products_true[hazards_pred == hazards_true],
    products_pred[hazards_pred == hazards_true],
    average='macro'
  )

  return (f1_hazards + f1_products) / 2.

# %% [markdown]
# ### Sub-Task 1:

# %%
predictions = predict(trial.title.to_list(), "bert_hazard_category")

# Decode predictions back to string labels
label_encoder = LabelEncoder()
label_encoder.fit(data['hazard-category'])

trial['bert-hazard-category'] = predict(trial.title.to_list(), "bert_hazard_category")
print(classification_report(trial['hazard-category'], trial['bert-hazard-category'], zero_division=0))

# %%
predictions = predict(trial.title.to_list(), "bert_product_category")

# Decode predictions back to string labels
label_encoder = LabelEncoder()
label_encoder.fit(data['product-category'])

trial['bert-product-category'] = predict(trial.title.to_list(), "bert_product_category")
print(classification_report(trial['product-category'], trial['bert-product-category'], zero_division=0))

# %%
print('Score Sub-Task 1:', compute_score(trial['hazard-category'], trial['product-category'], trial['bert-hazard-category'], trial['bert-product-category']))

# %% [markdown]
# ### Sub-Task 2:

# %%
predictions = predict(trial.title.to_list(), "bert_hazard")

# Decode predictions back to string labels
label_encoder = LabelEncoder()
label_encoder.fit(data['hazard'])

trial['bert-hazard'] = predict(trial.title.to_list(), "bert_hazard")
print(classification_report(trial['hazard'], trial['bert-hazard'], zero_division=0))

# %%
predictions = predict(trial.title.to_list(), "bert_product")

# Decode predictions back to string labels
label_encoder = LabelEncoder()
label_encoder.fit(data['product'])

trial['bert-product'] = predict(trial.title.to_list(), "bert_product")
print(classification_report(trial['product'], trial['bert-product'], zero_division=0))

# %%
print('Score Sub-Task 2:', compute_score(trial['hazard'], trial['product'], trial['bert-hazard'], trial['bert-product']))
